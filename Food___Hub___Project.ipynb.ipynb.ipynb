# %% [markdown]
# **QUESTION 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('foodhub_order.csv')
df.head ()
num_rows = df.shape[0]
num_columns = df.shape [1]
print ('Number of rows',num_rows)
print ('Number of columns',num_columns)
# Out:
# Number of rows 1898
# Number of columns 9

# %% [markdown]
# **QUESTION 2**

# %%
data_type =df.dtypes
print(data_type)
# Out:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object

# %% [markdown]
# **QUESTION 3**

# %%
missing_values =df.isnull().sum()
print(missing_values)
df.info ()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# ...

# %% [markdown]
# All columns have 1898 observations.
# Restaurant name  and cusine type should be categorical variable.

# %% [markdown]
# **QUESTION 4**

# %%
column_name ='food_preparation_time'
column_summary =df[column_name].describe().T
print(column_summary)
# Out:
# count    1898.000000
# mean       27.371970
# std         4.632481
# min        20.000000
# 25%        23.000000
# 50%        27.000000
# 75%        31.000000
# max        35.000000
# Name: food_preparation_time, dtype: float64

# %% [markdown]
# Minimum time it takes is 20 minutes.
# Average time restaurant takes is 27.37 minutes.
# Maximum time it takes is 35minutes.

# %% [markdown]
# **QUESTION 5**

# %%
from pandas._libs.hashtable import value_count
column_name= 'rating'
value_counts = df[column_name].value_counts()
print (value_counts)
# Out:
# Not given    736
# 5            588
# 4            386
# 3            188
# Name: rating, dtype: int64

# %% [markdown]
# There are 736 orders which are not given any ratings or are not rated.

# %% [markdown]
# **QUESTION 6**

# %%
df['order_id'].nunique()
# Out:
# 1898

# %%
df['customer_id'].nunique ()
# Out:
# 1200

# %%
df['restaurant_name'].nunique()
# Out:
# 178

# %%
df['cuisine_type'].nunique()
plt.figure(figsize=(15,5))
sns.countplot(data=df,x= 'cuisine_type')
# Out:
# <Axes: xlabel='cuisine_type', ylabel='count'>

# %% [markdown]
# American and Japanese are the most ordered cuisine type.
# Italian and Chinese are almost equally favored they have a minor difference of almost 50 counts.

# %%
sns.histplot (data=df ,x='cost_of_the_order')
plt.show()
sns.boxplot (data=df ,x="cost_of_the_order")
plt.show()

# %% [markdown]
# Cost of mainly the order is between 12 to 15 dollars.

# %%
df['day_of_the_week'].nunique()
sns.countplot(data=df,x= 'day_of_the_week')
# Out:
# <Axes: xlabel='day_of_the_week', ylabel='count'>

# %% [markdown]
# There are more orders on weekend in comparison to week , which makes sense.

# %%
df['rating'].nunique()
sns.countplot(data=df, x='rating')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# Most of the restaurants do not have any ratings.
# Less than 200 restaurants have the rating of three which is lowest.
# Almost 600 restaurants have highest rating of 5.

# %%
sns.histplot(data=df,x='food_preparation_time')
plt.show()
sns.boxplot(data=df,x='food_preparation_time')
plt.show()

# %% [markdown]
# Maximum time to prepare food is more than thirty four minutes.
# Most of the food is prepared in the range of 24 to 30 minutes.

# %%
sns.histplot(data=df,x='delivery_time')
plt.show()
sns.boxplot(data=df,x='delivery_time')
plt.show()

# %% [markdown]
# The maximum time to deliver food is 32.5 minutes.
# Maximum orders are delivered in betwween 27 to 29 minutes.

# %% [markdown]
# **QUESTION 7**

# %%
colunm_name = 'restaurant_name'
top_five_names=df [colunm_name].value_counts().head(5).index.tolist()
print ('the top five names are:',top_five_names)
# Out:
# the top five names are: ['Shake Shack', 'The Meatball Shop', 'Blue Ribbon Sushi', 'Blue Ribbon Fried Chicken', 'Parm']

# %% [markdown]
# **QUESTION 8**

# %%
df_weekend=df[df['day_of_the_week']=='Weekend']
df_weekend['cuisine_type'].value_counts().head()
# Out:
# American    415
# Japanese    335
# Italian     207
# Chinese     163
# Mexican      53
# Name: cuisine_type, dtype: int64

# %% [markdown]
#   It shows that American is the most popular cuisine on weekend.

# %% [markdown]
# **QUESTION 9**

# %%
df_greater_than_20=df[df['cost_of_the_order']>20]
print('The number of total orders that cost above 20 dollars is:',df_greater_than_20.shape[0])
percentage= (df_greater_than_20.shape[0]/df.shape[0]*100)
print('Percentage of orders above 20 dollars:',round(percentage,2),'%')
# Out:
# The number of total orders that cost above 20 dollars is: 555
# Percentage of orders above 20 dollars: 29.24 %

# %% [markdown]
# **QUESTION 10**

# %%
mean_order_delivery_time= df['delivery_time'].mean()
print('The mean delivery time for this dataset is',round(mean_order_delivery_time,2),'minutes')
# Out:
# The mean delivery time for this dataset is 24.16 minutes

# %% [markdown]
# **QUESTION 11**

# %%
df['customer_id'].value_counts().head(3)
# Out:
# 52832    13
# 47440    10
# 83287     9
# Name: customer_id, dtype: int64

# %% [markdown]
# The customer id's with the most amount of orders placed are 52832,47440 and 83287.

# %% [markdown]
# **QUESTION 12**

# %% [markdown]
# **CUISINE VS COST OF ORDER**

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='cuisine_type',y='cost_of_the_order',data=df,palette='PuBu')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Southern cuisine type has most fluctuating cost as well as highest cost of order.
# Korean is the least expensive cuisine to order.

# %% [markdown]
# **CUISINE VS FOOD PREPARATION TIME**

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x="cuisine_type" , y= "food_preparation_time",data =df ,palette= 'PuBu')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# 1.Southern food takes most preparation time.
# 2.Thai food has widest range for preparation time.
# 3.Korean cuisine takes least time for food preparation.
# 4.Mexican,American, Indian,Italian and Mediterranean food has
#   same preparation time  and have the same range for food preparation time.

# %% [markdown]
# **DAY OF THE WEEK VS DELIVERY TIME**

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x='day_of_the_week', y = 'delivery_time' , data= df ,palette ="PuBu")
plt.show()

# %% [markdown]
# The graph shows that on weekdays delivery time is higher than on weekend. It makes sense because on weekdays generally people call for delivey during rush hours.

# %%
df.groupby(['restaurant_name'])['cost_of_the_order'].sum().sort_values(ascending =False).head(14)
# Out:
# restaurant_name
# Shake Shack                      3579.53
# The Meatball Shop                2145.21
# Blue Ribbon Sushi                1903.95
# Blue Ribbon Fried Chicken        1662.29
# Parm                             1112.76
# RedFarm Broadway                  965.13
# RedFarm Hudson                    921.21
# TAO                               834.50
# Han Dynasty                       755.29
# Blue Ribbon Sushi Bar & Grill     666.62
# Rubirosa                          660.45
# Sushi of Gari 46                  640.87
# Nobu Next Door                    623.67
# Five Guys Burgers and Fries       506.47
# Name: cost_of_the_order, dtype: float64

# %% [markdown]
# ShakeShack and The Meatball shop are the highest yielding revenue restaurants.

# %% [markdown]
# **RATING VS DELIVERY TIME**

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='rating',y='delivery_time',data=df)
plt.show()

# %% [markdown]
# The restaurants with lowest ratings have highest delivery-time.
# So it can be assumed that delivery time is one of the major reason which can make individual decide to order or not to order from a particular restaurant.

# %% [markdown]
# **RATING VS FOOD PREPARATION TIME**

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='rating', y='food_preparation_time',data=df)
plt.show()

# %% [markdown]
# The food with the lowest rating has highest preparation time. So, it's kind of evident that customers prefer food which is easily available to them.

# %% [markdown]
# **RATING VS COST OF THE ORDER**

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x='rating',y='cost_of_the_order',data=df)
plt.show()

# %% [markdown]
# Again the results depict what is generally expected that lower the ratings higher the cost of the order.

# %% [markdown]
# **CORRELATION AMONG VARIABLES**

# %%
col_list=['cost_of_the_order','food_preparation_time' ,'delivery_time']
plt.figure(figsize=(15,7))
sns.heatmap(df[col_list].corr(),annot=True, vmin=-1,  vmax =1, fmt='0.2f',cmap='Spectral')
plt.show()

# %% [markdown]
# 1.   There are not strong correlations.
# 2.   If food prepration time is higher than cost of the order is
#      also higher and vice versa.
# 3.   Surprisingly if cost of the order is higher than delivery
#      time is less and vice versa.

# %% [markdown]
# **QUESTION 13**

# %%
df_rated=df[df['rating']!= 'Not given'].copy()
df_rated['rating'] =df_rated['rating'].astype('int')
df_rating_count=df_rated.groupby(['restaurant_name'])['rating'].count().sort_values(ascending=False) .reset_index()

# %%
count_values _greater_50= df_rating_count(['restaurant_name']>50).sum()
df_mean_4= df_rated[df_rated['restaurant_name'].isin(rest_names)].copy()
df_mean_4.groupby(['df_mean_4'])['rest_name'].mean().sort_values(ascending=False).reset_index().dropna()
# Out:
#   File "<ipython-input-132-89673b176367>", line 1
#     count_values _greater_50= df_rating_count(['restaurant_name']>50).sum()
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# **QUESTION 14**

# %%
def compute_rev(x):
    if x >  20:
         return x *0.25
    elif x > 5 :
           return x *0.15
    else:
           return x *0
    df['Revenue'] =df['def compute_rev(x)'] .apply(compute_rev)
    df.head()

# %%
total_rev= df ['Revenue'].multiply()
print('The net revenue is around',round(total_rev,2),"dollars")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# **QUESTION 15**

# %%
df['total_time']=df['food_preparation_time']+df['delivery_time']
df_greater_than_60= df[df['total_time']>60]
print('The percentage of orders that have 60 minuttes of total delivery time is:',df_greater_than_60)
# Out:
# The percentage of orders that have 60 minuttes of total delivery time is:       order_id  customer_id             restaurant_name    cuisine_type  \
# 7      1477859        89574                   Barbounia   Mediterranean
# 10     1477895       143926  Big Wong Restaurant _¤¾Ñ¼         Chinese
# 19     1477354        67487           Blue Ribbon Sushi        Japanese
# 24     1476714       363783                Cafe Mogador  Middle Eastern
# 54     1477760       130507           Jack's Wife Freda   Mediterranean
# ...        ...          ...                         ...             ...
# 1869   1476923        50199                 J. G. Melon        American
# 1873   1478148       261371                 Shake Shack        American
# 1875   1478039       292343                  Amy Ruth's        Southern
# 1880   1477466       222734                 Shake Shack        American
# 1889   1478190        94152            RedFarm Broadway         Chinese
#
# ...

# %% [markdown]
# **QUESTION 16**

# %%
print('The mean delivery time on weekdays is around', round(df[df['day_of_the_week']=='Weekday']['delivery_time'].mean()),'minutes')
print('The mean delivery time on weekends is around',round (df[df['day_of_the_week']=='Weekend']['delivery_time'].mean()),"minutes")
# Out:
# The mean delivery time on weekdays is around 28 minutes
# The mean delivery time on weekends is around 22 minutes
